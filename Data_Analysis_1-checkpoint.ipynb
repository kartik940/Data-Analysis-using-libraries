# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#loading Data
armsdata = pd.read_csv(r"C:\Users\karti\Desktop\armsdat.csv")

# %%
armsdata.head(5)
# Out:
#   Country/Region/Group  1950  1951  1952  1953  1954   1955  1956  1957  \
# 0          Afghanistan   NaN   NaN   NaN   NaN   NaN    4.0   7.0  89.0
# 1      African Union**   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN
# 2              Albania  20.0  10.0  11.0  20.0  22.0  132.0  98.0  42.0
# 3              Algeria   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN
# 4      Amal (Lebanon)*   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN
#
#     1958  ...   2012   2013   2014   2015    2016    2017    2018   2019  \
# 0  254.0  ...  523.0  235.0  288.0  116.0   174.0   252.0   322.0  396.0
# 1    NaN  ...    NaN    2.0    NaN    2.0     NaN     NaN     0.0    2.0
# 2   47.0  ...   15.0    7.0    7.0    7.0     NaN     2.0     3.0    5.0
# 3    NaN  ...  661.0  362.0  710.0  906.0  2911.0  1139.0  1291.0  164.0
# 4    NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN
#
#     2020  Total
# 0  240.0  16403
# 1    NaN     78
# 2    1.0   2771
# 3  661.0  32383
# ...

# %%
#transposing the data
data= transposed_data = armsdata.T

# %%
data.head(5)
# Out:
# Country/Region/Group  Afghanistan    African Union  Albania  Algeria  \
# Country/Region/Group  Afghanistan  African Union**  Albania  Algeria
# 1950                          NaN              NaN     20.0      NaN
# 1951                          NaN              NaN     10.0      NaN
# 1952                          NaN              NaN     11.0      NaN
# 1953                          NaN              NaN     20.0      NaN
#
# Country/Region/Group   Amal (Lebanon)   ANC (South Africa)  Angola  \
# Country/Region/Group  Amal (Lebanon)*  ANC (South Africa)*  Angola
# 1950                              NaN                  NaN     NaN
# 1951                              NaN                  NaN     NaN
# 1952                              NaN                  NaN     NaN
# 1953                              NaN                  NaN     NaN
#
# Country/Region/Group   Anti-Castro rebels (Cuba)  Argentina  \
# Country/Region/Group  Anti-Castro rebels (Cuba)*  Argentina
# ...

# %%
print (data.index)
# Out:
# Index(['Country/Region/Group', '1950', '1951', '1952', '1953', '1954', '1955',
#        '1956', '1957', '1958', '1959', '1960', '1961', '1962', '1963', '1964',
#        '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973',
#        '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982',
#        '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020', 'Total'],
#       dtype='object')

# %%
data = data.drop(index = 'Country/Region/Group')

# %%
data.head(2)
# Out:
# Country/Region/Group Afghanistan African Union Albania Algeria Amal (Lebanon)  \
# 1950                         NaN           NaN    20.0     NaN            NaN
# 1951                         NaN           NaN    10.0     NaN            NaN
#
# Country/Region/Group ANC (South Africa) Angola Anti-Castro rebels (Cuba)  \
# 1950                                NaN    NaN                       NaN
# 1951                                NaN    NaN                       NaN
#
# Country/Region/Group Argentina Armas (Guatemala)  ... Viet Nam Western Sahara  \
# 1950                      75.0               NaN  ...      NaN            NaN
# 1951                     445.0               NaN  ...      NaN            NaN
#
# Country/Region/Group Yemen Yemen Arab Republic Yugoslavia Zambia  \
# 1950                   NaN                 NaN        NaN    NaN
# 1951                   NaN                 NaN      182.0    NaN
#
# Country/Region/Group ZAPU (Zimbabwe) Zimbabwe    Total  year
# ...

# %%
data['Year'] = data.index.tolist()

# %%
data.index = data['Year']

# %%
data.tail(1)
# Out:
# Country/Region/Group Afghanistan African Union Albania Algeria Amal (Lebanon)  \
# Year
# Total                      16403            78    2771   32383             60
#
# Country/Region/Group ANC (South Africa) Angola Anti-Castro rebels (Cuba)  \
# Year
# Total                                 0   8544                         2
#
# Country/Region/Group Argentina Armas (Guatemala)  ... Western Sahara Yemen  \
# Year                                              ...
# Total                    12171                 8  ...             77  2443
#
# Country/Region/Group Yemen Arab Republic Yugoslavia Zambia ZAPU (Zimbabwe)  \
# Year
# Total                                 63      17476   1256               1
#
# Country/Region/Group Zimbabwe    Total   year   Year
# Year
# Total                     946  1976320  Total  Total
#
# [1 rows x 263 columns]

# %%
data['Year'] = data['Year'].apply(lambda x:int(x) if str(x).isdigit() else x)

# %%
data.tail(5)
# Out:
# Country/Region/Group Afghanistan African Union Albania Algeria Amal (Lebanon)  \
# Year
# 2017                       252.0           NaN     2.0  1139.0            NaN
# 2018                       322.0           0.0     3.0  1291.0            NaN
# 2019                       396.0           2.0     5.0   164.0            NaN
# 2020                       240.0           NaN     1.0   661.0            NaN
# Total                      16403            78    2771   32383             60
#
# Country/Region/Group ANC (South Africa) Angola Anti-Castro rebels (Cuba)  \
# Year
# 2017                                NaN  110.0                       NaN
# 2018                                NaN  272.0                       NaN
# 2019                                NaN  169.0                       NaN
# 2020                                NaN   51.0                       NaN
# Total                                 0   8544                         2
#
# ...

# %%
data = data.drop('Year', axis = 1)

# %%
data.fillna(0)
# Out:
# C:\Users\karti\AppData\Local\Temp\ipykernel_11672\1226986988.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.fillna(0)
# Country/Region/Group  Afghanistan  African Union  Albania  Algeria  \
# Year
# 1950                          0.0            0.0     20.0      0.0
# 1951                          0.0            0.0     10.0      0.0
# 1952                          0.0            0.0     11.0      0.0
# 1953                          0.0            0.0     20.0      0.0
# 1954                          0.0            0.0     22.0      0.0
# ...                           ...            ...      ...      ...
# 2017                        252.0            0.0      2.0   1139.0
# 2018                        322.0            0.0      3.0   1291.0
# ...
